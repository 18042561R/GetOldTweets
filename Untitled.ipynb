# %%
import pandas as pd
import numpy as np
import os
import warnings

warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')


import seaborn as sns

# %%
df = pd.read_csv('noisetweets.csv', parse_dates = True)

# %%
df.head(3).transpose()
# Out:
#                                                                    0  \
# date                                             2014-12-27 14:36:23
# favorites                                                          0
# hashtags                              #Kowloon #ExoticFood #HongKong
# mentions                                                    @Kowloon
# replies                                                            0
# retweets                                                           0
# text               Kowloon food. Noise louder than taste. yummy a...
# to                                                               NaN
# username                                                svetothefool
# tweet_clean        Kowloon food Noise louder than taste yummy any...
# hashtag_clean                            Kowloon ExoticFood HongKong
# tweet_sentiment                                              neutral
# hashtag_sentiment                                            neutral
#
# ...

# %%
df.dtypes
# Out:
# date                 object
# favorites             int64
# hashtags             object
# mentions             object
# replies               int64
# retweets              int64
# text                 object
# to                   object
# username             object
# tweet_clean          object
# hashtag_clean        object
# tweet_sentiment      object
# hashtag_sentiment    object
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# date                 datetime64[ns]
# favorites                     int64
# hashtags                     object
# mentions                     object
# replies                       int64
# retweets                      int64
# text                         object
# to                           object
# username                     object
# tweet_clean                  object
# hashtag_clean                object
# tweet_sentiment              object
# hashtag_sentiment            object
# dtype: object

# %%
df.head(3).transpose()
# Out:
#                                                                    0  \
# date                                             2014-12-27 14:36:23
# favorites                                                          0
# hashtags                              #Kowloon #ExoticFood #HongKong
# mentions                                                    @Kowloon
# replies                                                            0
# retweets                                                           0
# text               Kowloon food. Noise louder than taste. yummy a...
# to                                                               NaN
# username                                                svetothefool
# tweet_clean        Kowloon food Noise louder than taste yummy any...
# hashtag_clean                            Kowloon ExoticFood HongKong
# tweet_sentiment                                              neutral
# hashtag_sentiment                                            neutral
#
# ...

# %%
df.index = df['date']

del df['date']

# %%
df.head(8).transpose()
# Out:
# date                                             2014-12-27 14:36:23  \
# favorites                                                          0
# hashtags                              #Kowloon #ExoticFood #HongKong
# mentions                                                    @Kowloon
# replies                                                            0
# retweets                                                           0
# text               Kowloon food. Noise louder than taste. yummy a...
# to                                                               NaN
# username                                                svetothefool
# tweet_clean        Kowloon food Noise louder than taste yummy any...
# hashtag_clean                            Kowloon ExoticFood HongKong
# tweet_sentiment                                              neutral
# hashtag_sentiment                                            neutral
#
# ...

# %%
#df['2016-12'].transpose()

# %%
#df[df.index.month == 12]

# %%
sns.set(rc={'figure.figsize':(11, 4)})

# %%
#df['tweet_sentiments'].plot(linewidth=3);

# %%
#df.username.value_counts()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

sentenc = encoder.fit_transform(df['tweet_sentiment'])
hashenc = encoder.fit_transform(df['hashtag_sentiment'])

# %%
len(sentenc)
# Out:
# 876

# %%
df['encoded_sents'] = sentenc
df['hash_enc'] = hashenc

# %%
df.head().transpose()
# Out:
# date                                             2014-12-27 14:36:23  \
# favorites                                                          0
# hashtags                              #Kowloon #ExoticFood #HongKong
# mentions                                                    @Kowloon
# replies                                                            0
# retweets                                                           0
# text               Kowloon food. Noise louder than taste. yummy a...
# to                                                               NaN
# username                                                svetothefool
# tweet_clean        Kowloon food Noise louder than taste yummy any...
# hashtag_clean                            Kowloon ExoticFood HongKong
# tweet_sentiment                                              neutral
# hashtag_sentiment                                            neutral
# encoded_sents                                                      1
# ...

# %%
c = df.encoded_sents.value_counts()

# %%
df.encoded_sents
# Out:
# date
# 2014-12-27 14:36:23    1
# 2014-12-18 18:31:44    1
# 2014-12-15 23:25:09    1
# 2014-12-10 11:57:30    1
# 2014-11-29 18:11:45    2
# 2014-11-28 10:19:53    1
# 2014-11-25 15:19:10    2
# 2014-11-25 13:09:07    0
# 2014-11-24 22:01:47    2
# 2014-11-22 07:11:24    2
# 2014-11-20 12:03:36    1
# 2014-11-16 15:03:56    2
# 2014-11-16 03:29:49    1
# 2014-11-14 11:38:53    1
# 2014-11-09 13:35:13    2
# 2014-11-07 15:08:40    2
# 2014-10-30 18:21:47    1
# 2014-10-29 12:12:56    1
# 2014-10-27 05:23:17    0
# 2014-10-26 09:45:36    0
# 2014-10-23 14:41:45    2
# 2014-10-23 01:49:18    2
# 2014-10-21 06:15:02    2
# 2014-10-21 06:14:45    2
# 2014-10-16 23:46:06    0
# 2014-10-16 23:28:59    1
# 2014-10-16 23:27:42    1
# 2014-10-13 01:59:23    0
# 2014-10-02 16:11:26    1
# 2014-10-01 19:14:49    1
#                       ..
# 2014-03-09 13:05:20    2
# 2014-03-08 09:05:56    1
# 2014-03-08 01:39:30    2
# 2014-03-05 16:26:44    1
# 2014-03-04 12:21:49    1
# ...

# %%
#plt.plot(df['date'], df['encoded_sents'], 'b')
#plt.plot(df['date'], df['favorites'], 'b')
#plt.plot(df['date'], df['retweets'], 'k')

# %%
#df.index = df['date']

#del df['date']

# %%
#plt.subplots(figsize=(8,6))

sns.set(rc={'figure.figsize':(25, 5)})

df['encoded_sents'].plot(linewidth=1.5, ylim=(0,5));
df['hash_enc'].plot(linewidth=1.5, ylim=(0,5));

# %%
df.encoded_sents.plot()

# %%
ax = df.loc['2015', 'encoded_sents'].plot()

ax.set_ylabel('Tweets 0-Neg, 1-Pos, 2-Neu');

# %%
# sns.relplot(x="date", y="encoded_sents", data=df, kind='line')
